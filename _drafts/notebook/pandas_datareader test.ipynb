# %%
import pandas as pd

# %%
from pandas_datareader import data

# %%
data.DataReader('005930.KS', 'yahoo-actions', '2010-07-04','2016-07-08')
# Out:
#               action    value
# 2015-12-29  DIVIDEND  20000.0
# 2015-06-29  DIVIDEND   1000.0
# 2014-12-29  DIVIDEND  19500.0
# 2014-06-27  DIVIDEND    500.0
# 2013-12-27  DIVIDEND  13800.0
# 2013-06-27  DIVIDEND    500.0
# 2012-12-27  DIVIDEND   7500.0
# 2012-06-28  DIVIDEND    500.0
# 2011-12-28  DIVIDEND   5000.0
# 2011-06-29  DIVIDEND    500.0
# 2010-12-29  DIVIDEND   5000.0

# %%
data.YahooQuotesReader

# %%
data.DataReader('005930', 'google', '2010-07-04','2016-07-08')
# Out:
#                  Open       High        Low      Close   Volume
# Date
# 2010-07-05   763000.0   770000.0   761000.0   767000.0   199294
# 2010-07-06   762000.0   775000.0   755000.0   775000.0   355302
# 2010-07-07   780000.0   781000.0   765000.0   769000.0   321829
# 2010-07-08   783000.0   784000.0   770000.0   775000.0   292674
# 2010-07-09   779000.0   796000.0   773000.0   796000.0   362616
# 2010-07-12   799000.0   802000.0   792000.0   802000.0   245512
# 2010-07-13   798000.0   808000.0   794000.0   796000.0   292941
# 2010-07-14   813000.0   828000.0   813000.0   824000.0   661493
# 2010-07-15   825000.0   825000.0   818000.0   820000.0   276294
# 2010-07-16   816000.0   820000.0   802000.0   802000.0   335425
# 2010-07-19   786000.0   799000.0   786000.0   795000.0   278908
# 2010-07-20   795000.0   802000.0   786000.0   798000.0   230488
# 2010-07-21   817000.0   818000.0   806000.0   817000.0   325599
# 2010-07-22   812000.0   817000.0   801000.0   808000.0   305388
# ...

# %%
data.DataReader('005930.KS', 'yahoo', '2010-07-04','2016-07-08')
# Out:
#                  Open       High        Low      Close   Volume   Adj Close
# Date
# 2010-07-05   763000.0   770000.0   761000.0   767000.0   199900   723766.07
# 2010-07-06   762000.0   775000.0   755000.0   775000.0   357500   731315.13
# 2010-07-07   780000.0   781000.0   765000.0   769000.0   323600   725653.33
# 2010-07-08   783000.0   784000.0   770000.0   775000.0   295000   731315.13
# 2010-07-09   779000.0   796000.0   773000.0   796000.0   372100   751131.41
# 2010-07-12   799000.0   802000.0   792000.0   802000.0   251900   756793.20
# 2010-07-13   798000.0   808000.0   794000.0   796000.0   306700   751131.41
# 2010-07-14   813000.0   828000.0   813000.0   824000.0   663600   777553.12
# 2010-07-15   825000.0   825000.0   818000.0   820000.0   321200   773778.59
# 2010-07-16   816000.0   820000.0   802000.0   802000.0   338600   756793.20
# 2010-07-19   786000.0   799000.0   786000.0   795000.0   291700   750187.78
# ...

# %%
pd.set_option('max_rows',10)

# %%
pd.set_option('display.width',1000)

# %%
data.YahooDailyReader('005930.KS', '2010-07-04','2016-07-08', adjust_price=True).read().round(3)
# Out:
#                    Open         High          Low       Close  Volume  \
# Date
# 2010-07-05   719991.540   726596.967   718104.275   723766.07  199900
# 2010-07-06   719047.908   731315.130   712442.481   731315.13  357500
# 2010-07-07   736033.287   736976.919   721878.800   725653.33  323600
# 2010-07-08   738864.189   739807.822   726596.968   731315.13  295000
# 2010-07-09   735089.659   751131.410   729427.864   751131.41  372100
# ...                 ...          ...          ...         ...     ...
# 2016-07-04  1464000.000  1474000.000  1451000.000  1466000.00  159900
# 2016-07-05  1466000.000  1475000.000  1462000.000  1469000.00  157400
# 2016-07-06  1447000.000  1452000.000  1412000.000  1421000.00  334900
# 2016-07-07  1421000.000  1450000.000  1416000.000  1450000.00  229900
# 2016-07-08  1450000.000  1475000.000  1449000.000  1460000.00  269900
#
#             Adj_Ratio
# Date
# 2010-07-05      0.944
# 2010-07-06      0.944
# 2010-07-07      0.944
# ...

# %%
print(_7)
# Out:
#                    Open         High          Low       Close  Volume  Adj_Ratio
# Date
# 2010-07-05   719991.540   726596.967   718104.275   723766.07  199900      0.944
# 2010-07-06   719047.908   731315.130   712442.481   731315.13  357500      0.944
# 2010-07-07   736033.287   736976.919   721878.800   725653.33  323600      0.944
# 2010-07-08   738864.189   739807.822   726596.968   731315.13  295000      0.944
# 2010-07-09   735089.659   751131.410   729427.864   751131.41  372100      0.944
# ...                 ...          ...          ...         ...     ...        ...
# 2016-07-04  1464000.000  1474000.000  1451000.000  1466000.00  159900      1.000
# 2016-07-05  1466000.000  1475000.000  1462000.000  1469000.00  157400      1.000
# 2016-07-06  1447000.000  1452000.000  1412000.000  1421000.00  334900      1.000
# 2016-07-07  1421000.000  1450000.000  1416000.000  1450000.00  229900      1.000
# ...

# %%
data.YahooDailyReader('005930.KS', '2016-07-04','2016-07-08').read()
# Out:
#                  Open       High        Low      Close  Volume  Adj Close
# Date
# 2016-07-04  1464000.0  1474000.0  1451000.0  1466000.0  159900  1466000.0
# 2016-07-05  1466000.0  1475000.0  1462000.0  1469000.0  157400  1469000.0
# 2016-07-06  1447000.0  1452000.0  1412000.0  1421000.0  334900  1421000.0
# 2016-07-07  1421000.0  1450000.0  1416000.0  1450000.0  229900  1450000.0
# 2016-07-08  1450000.0  1475000.0  1449000.0  1460000.0  269900  1460000.0

# %%
data.DataReader('005930.KS','yahoo','2016-07-04','2016-07-08')
# Out:
#                  Open       High        Low      Close  Volume  Adj Close
# Date
# 2016-07-04  1464000.0  1474000.0  1451000.0  1466000.0  159900  1466000.0
# 2016-07-05  1466000.0  1475000.0  1462000.0  1469000.0  157400  1469000.0
# 2016-07-06  1447000.0  1452000.0  1412000.0  1421000.0  334900  1421000.0
# 2016-07-07  1421000.0  1450000.0  1416000.0  1450000.0  229900  1450000.0
# 2016-07-08  1450000.0  1475000.0  1449000.0  1460000.0  269900  1460000.0

# %%
print(_5)
# Out:
#                  Open       High        Low      Close  Volume  Adj Close
# Date
# 2016-07-04  1464000.0  1474000.0  1451000.0  1466000.0  159900  1466000.0
# 2016-07-05  1466000.0  1475000.0  1462000.0  1469000.0  157400  1469000.0
# 2016-07-06  1447000.0  1452000.0  1412000.0  1421000.0  334900  1421000.0
# 2016-07-07  1421000.0  1450000.0  1416000.0  1450000.0  229900  1450000.0
# 2016-07-08  1450000.0  1475000.0  1449000.0  1460000.0  269900  1460000.0

# %%
_12.read()
# Out:
#                     Open          High           Low       Close   Volume  \
# Date
# 2010-07-05  7.199915e+05  7.265970e+05  7.181043e+05   723766.07   199900
# 2010-07-06  7.190479e+05  7.313151e+05  7.124425e+05   731315.13   357500
# 2010-07-07  7.360333e+05  7.369769e+05  7.218788e+05   725653.33   323600
# 2010-07-08  7.388642e+05  7.398078e+05  7.265970e+05   731315.13   295000
# 2010-07-09  7.350897e+05  7.511314e+05  7.294279e+05   751131.41   372100
# 2010-07-12  7.539623e+05  7.567932e+05  7.473569e+05   756793.20   251900
# 2010-07-13  7.530187e+05  7.624550e+05  7.492441e+05   751131.41   306700
# 2010-07-14  7.671732e+05  7.813276e+05  7.671732e+05   777553.12   663600
# 2010-07-15  7.784968e+05  7.784968e+05  7.718913e+05   773778.59   321200
# 2010-07-16  7.700041e+05  7.737786e+05  7.567932e+05   756793.20   338600
# 2010-07-19  7.416951e+05  7.539623e+05  7.416951e+05   750187.78   291700
# 2010-07-20  7.501878e+05  7.567932e+05  7.416951e+05   753018.67   231500
# ...

# %%
data.DataReader?

# %%
data.YahooActionReader('005930.KS', '2010-07-04','2016-07-08').read()
# Out:
#               action    value
# 2015-12-29  DIVIDEND  20000.0
# 2015-06-29  DIVIDEND   1000.0
# 2014-12-29  DIVIDEND  19500.0
# 2014-06-27  DIVIDEND    500.0
# 2013-12-27  DIVIDEND  13800.0
# 2013-06-27  DIVIDEND    500.0
# 2012-12-27  DIVIDEND   7500.0
# 2012-06-28  DIVIDEND    500.0
# 2011-12-28  DIVIDEND   5000.0
# 2011-06-29  DIVIDEND    500.0
# 2010-12-29  DIVIDEND   5000.0
